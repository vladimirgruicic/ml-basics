# %%
polynomial-ridge-model-scaled.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 polynomial-ridge-model-scaled.py
#
# NameError: name 'polynomial' is not defined

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.8223434  0.84653522 0.83137554 0.82585006 0.82552854]
# Mean Cross-Validation R-squared Score: 0.8303265524358512
#
# Baseline Mean Squared Error (MSE): 84.24228090011638
# Baseline R-squared: -0.0018505167076265927
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 13.597732067315638
# R-squared on Test Data: 0.838289101955296
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.82248936 0.84631726 0.83147091 0.82586473 0.82554592]
# Mean Cross-Validation R-squared Score: 0.8303376357205898
#
# Baseline Mean Squared Error (MSE): 84.24228090011638
# Baseline R-squared: -0.0018505167076265927
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 13.599310786182384
# R-squared on Test Data: 0.8382703270563321
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.82372027 0.84401281 0.83222526 0.82584203 0.82554214]
# Mean Cross-Validation R-squared Score: 0.8302685017608304
#
# Baseline Mean Squared Error (MSE): 84.24228090011638
# Baseline R-squared: -0.0018505167076265927
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 13.624307913895255
# R-squared on Test Data: 0.83797304895503
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.84745891 0.83378065 0.83252238 0.82910376 0.8038434 ]
# Mean Cross-Validation R-squared Score: 0.8293418204035184
#
# Baseline Mean Squared Error (MSE): 89.50947590774751
# Baseline R-squared: -0.0002238465630388653
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 14.599288199341617
# R-squared on Test Data: 0.8368602200857717
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.99468377 0.99488578 0.99481465 0.99422854 0.99351836]
# Mean Cross-Validation R-squared Score: 0.9944262206501131
#
# Baseline Mean Squared Error (MSE): 89.50947590774751
# Baseline R-squared: -0.0002238465630388653
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 0.47996090977689454
# R-squared on Test Data: 0.9946366756982051
# Ridge model outperforms baseline.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /mnt/d/Projects/machine-learning/ml-basics/polynomial-ridge-model-scaled.py:74
#      71     print("Baseline outperforms ridge model.")
#      73 # Visualize the results
# ---> 74 plt.scatter(X_test, y_test, label='Test data')
#      75 plt.plot(X_test, y_pred_test_ridge_scaled, color='r', linestyle='-', linewidth=1, label='Predictions Ridge')
#      76 plt.xlabel('X')
#
# ...

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.82372027 0.84401281 0.83222526 0.82584203 0.82554214]
# Mean Cross-Validation R-squared Score: 0.8302685017608304
#
# Baseline Mean Squared Error (MSE): 84.24228090011638
# Baseline R-squared: -0.0018505167076265927
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 13.624307913895255
# R-squared on Test Data: 0.83797304895503
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.99468377 0.99488578 0.99481465 0.99422854 0.99351836]
# Mean Cross-Validation R-squared Score: 0.9944262206501131
#
# Baseline Mean Squared Error (MSE): 89.50947590774751
# Baseline R-squared: -0.0002238465630388653
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 0.47996090977689454
# R-squared on Test Data: 0.9946366756982051
# Ridge model outperforms baseline.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /mnt/d/Projects/machine-learning/ml-basics/polynomial-ridge-model-scaled.py:74
#      71     print("Baseline outperforms ridge model.")
#      73 # Visualize the results
# ---> 74 plt.scatter(X_test[:0], y_test, label='Test data')
#      75 plt.plot(X_test[:0], y_pred_test_ridge_scaled, color='r', linestyle='-', linewidth=1, label='Predictions Ridge')
#      76 plt.xlabel('X')
#
# ...

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.99468377 0.99488578 0.99481465 0.99422854 0.99351836]
# Mean Cross-Validation R-squared Score: 0.9944262206501131
#
# Baseline Mean Squared Error (MSE): 89.50947590774751
# Baseline R-squared: -0.0002238465630388653
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 0.47996090977689454
# R-squared on Test Data: 0.9946366756982051
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.99402737 0.99345921 0.99422648 0.99404248 0.99445347]
# Mean Cross-Validation R-squared Score: 0.9940418009458384
#
# Baseline Mean Squared Error (MSE): 81.97815854597407
# Baseline R-squared: -0.002442962946167193
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 0.45813151580540845
# R-squared on Test Data: 0.9943972662410684
# Ridge model outperforms baseline.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /mnt/d/Projects/machine-learning/ml-basics/polynomial-ridge-model-scaled.py:74
#      71     print("Baseline outperforms ridge model.")
#      73 # Visualize the results
# ---> 74 plt.scatter(X_test[:,0], y_test, label='Test data')
#      75 plt.plot(X_test[:,0], y_pred_test_ridge_scaled, color='r', linestyle='-', linewidth=1, label='Predictions Ridge')
#      76 plt.xlabel('X')
#
# ...

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.99402737 0.99345921 0.99422648 0.99404248 0.99445347]
# Mean Cross-Validation R-squared Score: 0.9940418009458384
#
# Baseline Mean Squared Error (MSE): 81.97815854597407
# Baseline R-squared: -0.002442962946167193
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 0.45813151580540845
# R-squared on Test Data: 0.9943972662410684
# Ridge model outperforms baseline.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /mnt/d/Projects/machine-learning/ml-basics/polynomial-ridge-model-scaled.py:74
#      71     print("Baseline outperforms ridge model.")
#      73 # Visualize the results
# ---> 74 plt.scatter(X_test[:,1], y_test, label='Test data')
#      75 plt.plot(X_test[:,1], y_pred_test_ridge_scaled, color='r', linestyle='-', linewidth=1, label='Predictions Ridge')
#      76 plt.xlabel('X')
#
# ...

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.99466004 0.99489496 0.99484071 0.99426738 0.99348604]
# Mean Cross-Validation R-squared Score: 0.9944298261812936
#
# Baseline Mean Squared Error (MSE): 89.50947590774751
# Baseline R-squared: -0.0002238465630388653
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 0.47941076255494885
# R-squared on Test Data: 0.9946428233196154
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.88576175 0.91151242 0.9199448  0.9096837  0.88799058]
# Mean Cross-Validation R-squared Score: 0.90297864889802
#
# Baseline Mean Squared Error (MSE): 96.11581906619327
# Baseline R-squared: -0.0005358379155417925
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 9.227847009425986
# R-squared on Test Data: 0.9039409773600952
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.9027597  0.9034269  0.90279615 0.90416488 0.90486595]
# Mean Cross-Validation R-squared Score: 0.9036027144469344
#
# Baseline Mean Squared Error (MSE): 91.0838550903024
# Baseline R-squared: -1.1186676474039814e-07
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 8.658581108060831
# R-squared on Test Data: 0.9049383442533917
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.90715845 0.90769761 0.9065478  0.90813285 0.90917683]
# Mean Cross-Validation R-squared Score: 0.9077427068065342
#
# Baseline Mean Squared Error (MSE): 91.0838550903024
# Baseline R-squared: -1.1186676474039814e-07
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 8.284099931714216
# R-squared on Test Data: 0.9090497338939305
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.90507146 0.90548674 0.90400736 0.90577293 0.90723645]
# Mean Cross-Validation R-squared Score: 0.9055149862011465
#
# Baseline Mean Squared Error (MSE): 91.0838550903024
# Baseline R-squared: -1.1186676474039814e-07
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 8.483368854294435
# R-squared on Test Data: 0.9068619812491371
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.07684613 0.09000235 0.08384203 0.09127314 0.09677065]
# Mean Cross-Validation R-squared Score: 0.08774686031363901
#
# Baseline Mean Squared Error (MSE): 913.9503646724207
# Baseline R-squared: -3.329208147340168e-05
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 828.5537289160408
# R-squared on Test Data: 0.0934066605561561
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.07684641 0.09000217 0.08384199 0.09127323 0.09677052]
# Mean Cross-Validation R-squared Score: 0.08774686632771238
#
# Baseline Mean Squared Error (MSE): 913.9503646724207
# Baseline R-squared: -3.329208147340168e-05
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 828.5538129285197
# R-squared on Test Data: 0.09340656863073094
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.26715688 0.28247896 0.27392731 0.28438143 0.29205726]
# Mean Cross-Validation R-squared Score: 0.28000036781218196
#
# Baseline Mean Squared Error (MSE): 291.1281102936486
# Baseline R-squared: -2.160002404005823e-05
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 207.2773666841726
# R-squared on Test Data: 0.2880047080606559
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.99350473 0.99345476 0.99336102 0.9934572  0.993584  ]
# Mean Cross-Validation R-squared Score: 0.9934723405912702
#
# Baseline Mean Squared Error (MSE): 82.8844492015981
# Baseline R-squared: -1.745829609323124e-06
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 0.5354605747787985
# R-squared on Test Data: 0.9935396625692796
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model-scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.99350773 0.99345081 0.99335653 0.99345589 0.9935795 ]
# Mean Cross-Validation R-squared Score: 0.9934700904269927
#
# Baseline Mean Squared Error (MSE): 82.8844492015981
# Baseline R-squared: -1.745829609323124e-06
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 0.535583320081118
# R-squared on Test Data: 0.9935381816459243
# Ridge model outperforms baseline.
