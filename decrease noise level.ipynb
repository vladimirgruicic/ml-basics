# %%
# %run main.py
# Out:
# First 5 elements of X:
# [[1.54264129]
#  [0.0415039 ]
#  [1.26729647]
#  [1.49760777]
#  [0.99701402]]
#
# First 5 elements of y:
# [[8.44679797]
#  [3.55994607]
#  [7.62703417]
#  [7.96646004]
#  [7.63218041]]
#
# Intercept [4.20874068]
# Slope [[2.78830567]]
#
# Predicted values for X_new:
# [[4.20874068]
#  [9.78535202]]
