# %%
# %run polynomial-feature.py

# %%
# %run polynomial-feature.py

# %%
# %run polynomial-feature.py

# %%
# %run polynomial-feature.py

# %%
# %run polynomial-feature.py

# %%
# %run polynomial-feature.py
