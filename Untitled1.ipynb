# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.09640030614277344
# R-squared on Test Data: 0.9830660214541531

# %%
# %run polynomial-feature-test-train-data.py
# Out:
#   File /mnt/d/Projects/machine-learning/ml-basics/polynomial-feature-test-train-data.py:37
#     plt.plot(X_test, y_pred_test, 'r-', color='g',, linestyle='-', linewidth=2, label='Predictions')
#                                                   ^
# SyntaxError: invalid syntax

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.09640030614277344
# R-squared on Test Data: 0.9830660214541531
# /mnt/d/Projects/machine-learning/ml-basics/polynomial-feature-test-train-data.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(X_test, y_pred_test, 'r-', color='g',, linestyle='-', linewidth=2, label='Predictions')
# /mnt/d/Projects/machine-learning/ml-basics/polynomial-feature-test-train-data.py:37: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(X_test, y_pred_test, 'r-', color='g',, linestyle='-', linewidth=2, label='Predictions')

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.09640030614277344
# R-squared on Test Data: 0.9830660214541531

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.09640030614277344
# R-squared on Test Data: 0.9830660214541531

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.09597286856500169
# R-squared on Test Data: 0.9831411064726691

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.08573130361988422
# R-squared on Test Data: 0.9827078398173978

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.08749724609076164
# R-squared on Test Data: 0.983508236738793

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.08418074473068486
# R-squared on Test Data: 0.9840956199538967

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.08440540606340997
# R-squared on Test Data: 0.9842801555316043

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.08339885388479003
# R-squared on Test Data: 0.9845978755635614

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.08339756275139228
# R-squared on Test Data: 0.98458760757701

# %%
# %run polynomial-feature-test-train-data.py

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.08339886929512229
# R-squared on Test Data: 0.9845873661195378

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.0833978517408763
# R-squared on Test Data: 0.9845875541699416

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 3.05994349279162
# R-squared on Test Data: 0.4345032594817424

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.0833978517408763
# R-squared on Test Data: 0.9845875541699416

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.08339880200693284
# R-squared on Test Data: 0.984587378554817
