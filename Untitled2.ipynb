# %%
# %run polynomial-feature-test-train-data.py
# Out:
# MEan Squared Error (MSE) on Test Data: 0.08339756275139228
# R-squared on Test Data: 0.98458760757701

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.08339756275139228
# R-squared on Test Data: 0.98458760757701
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.08339756154389136
# R-squared on Test Data: 0.9845876078001637

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.08339756275139228
# R-squared on Test Data: 0.98458760757701
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.08339755074370343
# R-squared on Test Data: 0.9845876097961062

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.08339886929512229
# R-squared on Test Data: 0.9845873661195378
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.08339768384931211
# R-squared on Test Data: 0.9845875851973552

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.08330782555926199
# R-squared on Test Data: 0.9846197596455708
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.08330779029658028
# R-squared on Test Data: 0.9846197661557458

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.0827338312101181
# R-squared on Test Data: 0.9848297812932741
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.08278411435987468
# R-squared on Test Data: 0.9848205612877707

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /mnt/d/Projects/machine-learning/ml-basics/polynomial-feature-test-train-data.py:46
#      43 r_squared_test_ridge = r2_score(y_test, y_pred_test_ridge)
#      45 # Calculate baseline prediction
# ---> 46 baseline_prediction = np.MEan(y_train)
#      47 baseline_predictions = np.full_like(y_test, fill_value=baseline_prediction)
#      49 # Evaluate baseline performance
#
# File /mnt/d/Projects/machine-learning/ml-basics/venv/lib/python3.10/site-packages/numpy/__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'MEan'

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# Baseline Mean Squared Error (MSE): 5.453979249798573
# Baseline R-squared: -5.108951452159616e-05
#
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.0827338312101181
# R-squared on Test Data: 0.9848297812932741
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.08278411435987468
# R-squared on Test Data: 0.9848205612877707
# Linear model outperforms baseline.
# Ridge model outperforms baseline.

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# Baseline Mean Squared Error (MSE): 5.453979249798573
# Baseline R-squared: -5.108951452159616e-05
#
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.0827338312101181
# R-squared on Test Data: 0.9848297812932741
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.08278411435987468
# R-squared on Test Data: 0.9848205612877707
# Linear model outperforms baseline.
# Ridge model outperforms baseline.

# %%
# %run polynomial-feature-test-train-data.py
# Out:
# Baseline Mean Squared Error (MSE): 5.453979249798573
# Baseline R-squared: -5.108951452159616e-05
#
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.0827338312101181
# R-squared on Test Data: 0.9848297812932741
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.08278411435987468
# R-squared on Test Data: 0.9848205612877707
# Linear model outperforms baseline.
# Ridge model outperforms baseline.

# %%
# %run polynomial-linear-model.py
# Out:
# Baseline Mean Squared Error (MSE): 5.453979249798573
# Baseline R-squared: -5.108951452159616e-05
#
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.0827338312101181
# R-squared on Test Data: 0.9848297812932741
# Linear model outperforms baseline.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /mnt/d/Projects/machine-learning/ml-basics/polynomial-linear-model.py:57
#      54 else:
#      55     print("Baseline outperforms linear model.")
# ---> 57 if mse_test_ridge < baseline_mse:
#      58     print("Ridge model outperforms baseline.")
#      59 else:
#
# NameError: name 'mse_test_ridge' is not defined

# %%
# %run polynomial-linear-model.py
# Out:
# Baseline Mean Squared Error (MSE): 5.453979249798573
# Baseline R-squared: -5.108951452159616e-05
#
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.0827338312101181
# R-squared on Test Data: 0.9848297812932741
# Linear model outperforms baseline.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /mnt/d/Projects/machine-learning/ml-basics/polynomial-linear-model.py:63
#      60 bar_width = 0.35
#      61 index = np.arange(len(models))
# ---> 63 plt.bar(index, mse_values, bar_width, label='MSE')
#      64 plt.bar(index + bar_width, r_squared_values, bar_width, label='R-squared')
#      66 plt.xlabel('Models')
#
# NameError: name 'mse_values' is not defined

# %%
# %run polynomial-linear-model.py
# Out:
# Baseline Mean Squared Error (MSE): 5.453979249798573
# Baseline R-squared: -5.108951452159616e-05
#
# Linear Regression:
# MEan Squared Error (MSE) on Test Data: 0.0827338312101181
# R-squared on Test Data: 0.9848297812932741
# Linear model outperforms baseline.

# %%
# %run polynomial-ridge-model.py
# Out:
# Baseline Mean Squared Error (MSE): 5.453979249798573
# Baseline R-squared: -5.108951452159616e-05
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.08278411435987468
# R-squared on Test Data: 0.9848205612877707
# Ridge model outperforms baseline.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /mnt/d/Projects/machine-learning/ml-basics/polynomial-ridge-model.py:62
#      60 # Visualize the results
#      61 plt.scatter(X_test, y_test, label='Test data')
# ---> 62 plt.plot(X_test, y_pred_test_linear, color='g', linestyle='-', linewidth=1, label='Predictions Linear')
#      63 plt.plot(X_test, y_pred_test_ridge, color='r', linestyle='-', linewidth=1, label='Predictions Ridge')
#      64 plt.xlabel('X')
#
# NameError: name 'y_pred_test_linear' is not defined

# %%
# %run polynomial-ridge-model.py
# Out:
# Baseline Mean Squared Error (MSE): 5.453979249798573
# Baseline R-squared: -5.108951452159616e-05
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.08278411435987468
# R-squared on Test Data: 0.9848205612877707
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model.py
# Out:
# Baseline Mean Squared Error (MSE): 5.326152684825498
# Baseline R-squared: -75.92018252557027
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 1.9579859198894674
# R-squared on Test Data: -27.2771905449663
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model.py
# Out:
# Baseline Mean Squared Error (MSE): 5.494905183959075
# Baseline R-squared: -0.9376345092880594
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.3204086768060955
# R-squared on Test Data: 0.8870162653457281
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model.py
# Out:
# Baseline Mean Squared Error (MSE): 4.540533341705733
# Baseline R-squared: -0.13663612242389678
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.11141128039490096
# R-squared on Test Data: 0.9721103059459598
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model.py
# Out:
# Baseline Mean Squared Error (MSE): 4.540533341705733
# Baseline R-squared: -0.13663612242389678
#
# Ridge Regression:
# MEan Squared Error (MSE) on Test Data: 0.11141128039490096
# R-squared on Test Data: 0.9721103059459598
# Ridge model outperforms baseline.

# %%
# %run polynomial-ridge-model_scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.9851156  0.98677007 0.98077275 0.97076414 0.97871875]
# Mean Cross-Validation R-squared Score: 0.9804282624338072
#
# Baseline Mean Squared Error (MSE): 4.540533341705733
# Baseline R-squared: -0.13663612242389678
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 0.09588173887312128
# R-squared on Test Data: 0.9759978311616001

# %%
# %run polynomial-ridge-model_scaled.py
# Out:
# Cross-Validation R-squared Scores: [0.9851156  0.98677007 0.98077275 0.97076414 0.97871875]
# Mean Cross-Validation R-squared Score: 0.9804282624338072
#
# Baseline Mean Squared Error (MSE): 4.540533341705733
# Baseline R-squared: -0.13663612242389678
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 0.09588173887312128
# R-squared on Test Data: 0.9759978311616001
# Ridge model outperforms baseline.
