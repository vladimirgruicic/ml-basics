# %%
# %run main.py
# Out:
# First 5 elements of X:
# [[1.54264129]
#  [0.0415039 ]
#  [1.26729647]
#  [1.49760777]
#  [0.99701402]]
#
# First 5 elements of y:
# [[8.26567207]
#  [2.99538045]
#  [7.45217893]
#  [7.44009677]
#  [8.27331875]]
#
# Intercept [4.41748137]
# Slope [[2.57661134]]
#
# Predicted values for X_new:
# [[4.41748137]
#  [9.57070405]]
