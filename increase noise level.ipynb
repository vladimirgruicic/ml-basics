# %%
# %run main.py
# Out:
# First 5 elements of X:
# [[1.54264129]
#  [0.0415039 ]
#  [1.26729647]
#  [1.49760777]
#  [0.99701402]]
#
# First 5 elements of y:
# [[ 6.81666493]
#  [-1.52114456]
#  [ 6.05333703]
#  [ 3.22919069]
#  [13.40242545]]
#
# Intercept [6.08740683]
# Slope [[0.8830567]]
#
# Predicted values for X_new:
# [[6.08740683]
#  [7.85352023]]
